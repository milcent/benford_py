# %%
import pandas as pd
import benford as be
import numpy as np
import matplotlib.pyplot as plt

# %%
pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd
# Out:
# /home/milcent

# %%
cd Documentos/Benford\ Datasets
# Out:
# /home/milcent/Documentos/Benford Datasets

# %%
ls
# Out:
# layout_01_01_200812.CSV  razao_contas_a_pagar_banco_30092006_a_31122010.xls
# layout_01_11_200812.CSV

# %%
r = pd.read_excel('razao_contas_a_pagar_banco_30092006_a_31122010.xls',\
                  skiprows=6, parse_cols=[0,1,2,3,5,6,7,8,9],header=0)

# %%
#r = r.dropna(how='all')
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63666 entries, 0 to 63665
# Data columns (total 9 columns):
# Dia                 54333 non-null object
# Ano                 63649 non-null float64
# Remessa - Origem    54333 non-null object
# ContraPartida       54333 non-null object
# Lancto              54333 non-null object
# Destino             42015 non-null float64
# Complemento         54333 non-null object
# Debito              21664 non-null object
# Credito             34797 non-null object
# dtypes: float64(2), object(7)
# memory usage: 4.9+ MB

# %%
#r=r[r.Dia.notnull()]
r.head()
# Out:
#      Dia   Ano Remessa - Origem        ContraPartida               Lancto  \
# 0    NaN   NaN              NaN                  NaN                  NaN
# 1    NaN   NaN              NaN                  NaN                  NaN
# 2    NaN   NaN              NaN                  NaN                  NaN
# 3  02/10  2006   000000-MANUAIS  8.1.7.06.00.0 279.0  00019 0004602584-01
# 4    NaN  2006              NaN                  NaN                  NaN
#
#    Destino                                        Complemento      Debito  \
# 0      NaN                                                NaN         NaN
# 1      NaN                                                NaN         NaN
# 2      NaN                                                NaN         NaN
# 3       19  INTEGRAÇAO DEWIN  EST DE LANÇ  4583382 CADAST ...  171.709,87
# 4      NaN                                                NaN         NaN
#
#   Credito
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
df = be.firstTwoDigits(r.Debito, plot=True)
# Out:
# Discarded 1226 values lower than 10, corresponding to 5.66 percent of the sample.
#
# The 15 highest Z scores are:
#
#              Expected     Found    Z_test
# First_2_Dig
# 50           0.008600  0.014287  8.804808
# 35           0.012234  0.016440  5.469132
# 60           0.007179  0.009590  4.083500
# 30           0.014240  0.017614  4.070919
# 25           0.017033  0.020354  3.669071
# 20           0.021189  0.024415  3.202408
# 48           0.008955  0.011009  3.117146
# 53           0.008118  0.006165  3.111346
# 70           0.006160  0.007829  3.048034
# 13           0.032185  0.028427  3.043461
# 65           0.006631  0.005137  2.630111
# 57           0.007553  0.005969  2.615291
# 45           0.009545  0.011302  2.583554
# 26           0.016390  0.014189  2.478361
# 86           0.005021  0.003816  2.436069
#
# Mean Absolute Deviation = 0.000976076172965
# For the First Two Digits:
# 		- 0.0000 to 0.0012: Close Conformity
# 		- 0.0012 to 0.0018: Acceptable Conformity
# ...

# %%
df.Expected[0:1]
# Out:
# First_2_Dig
# 10             0.041393
# Name: Expected, dtype: float64
