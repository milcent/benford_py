# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import benford as bf
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
# %matplotlib inline

# %%
#     import seaborn
#     seaborn.set()

# %%
cd
# Out:
# /home/milcent

# %%
cd Dropbox/IBMEC/00TCC/
# Out:
# /home/milcent/Dropbox/IBMEC/00TCC

# %%
df = pd.read_csv('BENFORD 3-3.csv', sep=';', thousands='.', decimal=',')
df.head()
# Out:
#     2012   2013   2014   2015
# 0    NaN    NaN    NaN    NaN
# 1    NaN    NaN    NaN    NaN
# 2  491.0  346.0  271.0  201.0
# 3    NaN    NaN    NaN    NaN
# 4    NaN    NaN    NaN    NaN

# %%
df.dropna(how='all', inplace=True)
df.head()
# Out:
#       2012   2013   2014   2015
# 2    491.0  346.0  271.0  201.0
# 15    12.0  157.0   51.0   48.0
# 87   100.0   24.0    NaN    NaN
# 153  402.0  473.0  322.0  249.0
# 186    NaN    NaN  190.0  101.0

# %%
y_12 = bf.Analysis(df['2012'], dec=0)
# Out:
# Initialized sequence with 8647 registries.

# %%
y_12.first_digits(1, conf_level=99.999,show_high_Z='all')
# Out:
# ---Test performed on 8647 registries.---
#
#
# The entries with the significant deviations are:
#
# Empty DataFrame
# Columns: [Expected, Found, Z_test]
# Index: []
#
# The Mean Absolute Deviation is 0.00478911447666
# 	For the First Digit:
# 	- 0.0000 to 0.0006: Close Conformity
# 	- 0.0006 to 0.0012: Acceptable Conformity
# 	- 0.0012 to 0.0015: Marginally Acceptable Conformity
# 	- Above 0.0015: Nonconformity

# %%
sd_12 = y_12.second_digit(conf_level=99,show_high_Z='all', ret=True, plot=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-37242ff4adba> in <module>()
# ----> 1 sd_12 = y_12.second_digit(conf_level=99,show_high_Z='all', ret=True, plot=False)
#
# TypeError: second_digit() got an unexpected keyword argument 'ret'

# %%
y_12.first_digits(2, conf_level=99,show_high_Z='all')
# Out:
# ---Test performed on 8647 registries.---
#
#
# The entries with the significant deviations are:
#
#              Expected     Found    Z_test
# First_2_Dig
# 69           0.006249  0.003469  3.279918
# 29           0.014723  0.010524  3.242175
# 31           0.013788  0.009946  3.064235
# 87           0.004963  0.007170  2.919883
#
# The Mean Absolute Deviation is 0.00100410816402
# 	For the First Two Digits:
# 	- 0.0000 to 0.0012: Close Conformity
# 	- 0.0012 to 0.0018: Acceptable Conformity
# 	- 0.0018 to 0.0022: Marginally Acceptable Conformity
# 	- Above 0.0022: Nonconformity

# %%
y_13 = bf.Analysis(df['2013'], dec=0)
# Out:
# Initialized sequence with 8413 registries.

# %%
y_13.first_digits(1, conf_level=99,show_high_Z='all')
# Out:
# ---Test performed on 8413 registries.---
#
#
# The entries with the significant deviations are:
#
# Empty DataFrame
# Columns: [Expected, Found, Z_test]
# Index: []
#
# The Mean Absolute Deviation is 0.00366486952125
# 	For the First Digit:
# 	- 0.0000 to 0.0006: Close Conformity
# 	- 0.0006 to 0.0012: Acceptable Conformity
# 	- 0.0012 to 0.0015: Marginally Acceptable Conformity
# 	- Above 0.0015: Nonconformity

# %%
y_13.second_digit(conf_level=99,show_high_Z='all')
# Out:
# ---Test performed on 8413 registries.---
#
#
# The entries with the significant deviations are:
#
#          Expected     Found    Z_test
# Sec_Dig
# 0        0.119679  0.130393  3.027639
#
# The Mean Absolute Deviation is 0.00287663250353
# 	For the Second Digits:
# 	- 0.0000 to 0.0008: Close Conformity
# 	- 0.0008 to 0.0010: Acceptable Conformity
# 	- 0.0010 to 0.0012: Marginally Acceptable Conformity
# 	- Above 0.0012: Nonconformity

# %%
y_13.first_digits(2, conf_level=99,show_high_Z='all')
# Out:
# ---Test performed on 8413 registries.---
#
#
# The entries with the significant deviations are:
#
#              Expected     Found    Z_test
# First_2_Dig
# 50             0.0086  0.011411  2.792017
#
# The Mean Absolute Deviation is 0.000796936164409
# 	For the First Two Digits:
# 	- 0.0000 to 0.0012: Close Conformity
# 	- 0.0012 to 0.0018: Acceptable Conformity
# 	- 0.0018 to 0.0022: Marginally Acceptable Conformity
# 	- Above 0.0022: Nonconformity

# %%
y_14 = bf.Analysis(df['2014'], dec=0)
# Out:
# Initialized sequence with 8034 registries.

# %%
y_14.first_digits(1, conf_level=99,show_high_Z='all')
# Out:
# ---Test performed on 8034 registries.---
#
#
# The entries with the significant deviations are:
#
# Empty DataFrame
# Columns: [Expected, Found, Z_test]
# Index: []
#
# The Mean Absolute Deviation is 0.00265307711759
# 	For the First Digit:
# 	- 0.0000 to 0.0006: Close Conformity
# 	- 0.0006 to 0.0012: Acceptable Conformity
# 	- 0.0012 to 0.0015: Marginally Acceptable Conformity
# 	- Above 0.0015: Nonconformity

# %%
y_14.second_digit(conf_level=99,show_high_Z='all')
# Out:
# ---Test performed on 8034 registries.---
#
#
# The entries with the significant deviations are:
#
# Empty DataFrame
# Columns: [Expected, Found, Z_test]
# Index: []
#
# The Mean Absolute Deviation is 0.00220539420319
# 	For the Second Digits:
# 	- 0.0000 to 0.0008: Close Conformity
# 	- 0.0008 to 0.0010: Acceptable Conformity
# 	- 0.0010 to 0.0012: Marginally Acceptable Conformity
# 	- Above 0.0012: Nonconformity

# %%
y_14.first_digits(2, conf_level=99,show_high_Z='all')
# Out:
# ---Test performed on 8034 registries.---
#
#
# The entries with the significant deviations are:
#
#              Expected     Found    Z_test
# First_2_Dig
# 94           0.004596  0.006597  2.652045
# 81           0.005329  0.003236  2.576284
#
# The Mean Absolute Deviation is 0.000834135412723
# 	For the First Two Digits:
# 	- 0.0000 to 0.0012: Close Conformity
# 	- 0.0012 to 0.0018: Acceptable Conformity
# 	- 0.0018 to 0.0022: Marginally Acceptable Conformity
# 	- Above 0.0022: Nonconformity

# %%
y_15 = bf.Analysis(df['2015'], dec=0)
# Out:
# Initialized sequence with 7643 registries.

# %%
y_15.first_digits(1, conf_level=99,show_high_Z='all')
# Out:
# ---Test performed on 7643 registries.---
#
#
# The entries with the significant deviations are:
#
# Empty DataFrame
# Columns: [Expected, Found, Z_test]
# Index: []
#
# The Mean Absolute Deviation is 0.00306753435344
# 	For the First Digit:
# 	- 0.0000 to 0.0006: Close Conformity
# 	- 0.0006 to 0.0012: Acceptable Conformity
# 	- 0.0012 to 0.0015: Marginally Acceptable Conformity
# 	- Above 0.0015: Nonconformity

# %%
y_15.second_digit(conf_level=99,show_high_Z='all')
# Out:
# ---Test performed on 7643 registries.---
#
#
# The entries with the significant deviations are:
#
# Empty DataFrame
# Columns: [Expected, Found, Z_test]
# Index: []
#
# The Mean Absolute Deviation is 0.00217019158545
# 	For the Second Digits:
# 	- 0.0000 to 0.0008: Close Conformity
# 	- 0.0008 to 0.0010: Acceptable Conformity
# 	- 0.0010 to 0.0012: Marginally Acceptable Conformity
# 	- Above 0.0012: Nonconformity

# %%
y_15.first_digits(2, conf_level=99,show_high_Z='all')
# Out:
# ---Test performed on 7643 registries.---
#
#
# The entries with the significant deviations are:
#
#              Expected     Found    Z_test
# First_2_Dig
# 78           0.005532  0.007850  2.731859
# 41           0.010465  0.007458  2.583819
#
# The Mean Absolute Deviation is 0.00103347885118
# 	For the First Two Digits:
# 	- 0.0000 to 0.0012: Close Conformity
# 	- 0.0012 to 0.0018: Acceptable Conformity
# 	- 0.0018 to 0.0022: Marginally Acceptable Conformity
# 	- Above 0.0022: Nonconformity

# %%
ys = pd.concat([df['2012'],df['2013'],df['2014'],df['2015']], ignore_index=True)
len(ys)
# Out:
# 37888

# %%
y_all = bf.Analysis(ys, dec=0)
# Out:
# Initialized sequence with 32737 registries.

# %%
y_all.first_digits(1, conf_level=99, show_high_Z='all')
# Out:
# ---Test performed on 32737 registries.---
#
#
# The entries with the significant deviations are:
#
# Empty DataFrame
# Columns: [Expected, Found, Z_test]
# Index: []
#
# The Mean Absolute Deviation is 0.00164909150297
# 	For the First Digit:
# 	- 0.0000 to 0.0006: Close Conformity
# 	- 0.0006 to 0.0012: Acceptable Conformity
# 	- 0.0012 to 0.0015: Marginally Acceptable Conformity
# 	- Above 0.0015: Nonconformity

# %%
y_all.second_digit(conf_level=99, show_high_Z='all')
# Out:
# ---Test performed on 32737 registries.---
#
#
# The entries with the significant deviations are:
#
#          Expected     Found    Z_test
# Sec_Dig
# 0        0.119679  0.125302  3.134076
#
# The Mean Absolute Deviation is 0.00158696059915
# 	For the Second Digits:
# 	- 0.0000 to 0.0008: Close Conformity
# 	- 0.0008 to 0.0010: Acceptable Conformity
# 	- 0.0010 to 0.0012: Marginally Acceptable Conformity
# 	- Above 0.0012: Nonconformity

# %%
y_all.first_digits(2, conf_level=99, show_high_Z='all')
# Out:
# ---Test performed on 32737 registries.---
#
#
# The entries with the significant deviations are:
#
#              Expected     Found    Z_test
# First_2_Dig
# 82           0.005264  0.006751  3.716822
# 50           0.008600  0.010264  3.259491
# 29           0.014723  0.012738  2.982505
#
# The Mean Absolute Deviation is 0.000452778856081
# 	For the First Two Digits:
# 	- 0.0000 to 0.0012: Close Conformity
# 	- 0.0012 to 0.0018: Acceptable Conformity
# 	- 0.0018 to 0.0022: Marginally Acceptable Conformity
# 	- Above 0.0022: Nonconformity

# %%
y_15.mantissas()
# Out:
# The Mantissas MEAN is 0.499804151984. Ref: 0.5.
# The Mantissas VARIANCE is 0.0847154080266. Ref: 0.83333.
