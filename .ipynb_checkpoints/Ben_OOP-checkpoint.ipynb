# %%
pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import numpy as np
import ben_oop as o

# %%
cd /home/milcent/Documentos/Benford\ Datasets
# Out:
# /home/milcent/Documentos/Benford Datasets

# %%
ls
# Out:
# layout_01_01_200812.CSV  razao_contas_a_pagar_30092006_31122010.xls
# layout_01_11_200812.CSV  table.csv

# %% [markdown]
# ## Pular para o início com o arquivo .csv

# %%
r = pd.read_excel('razao_contas_a_pagar_30092006_31122010.xls',\
                  skiprows=6, parse_cols=[0,1,2,3,5,6,7,8,9],header=0)

# %%
r.Ano = r.Ano.apply(o._tint_)
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63666 entries, 0 to 63665
# Data columns (total 9 columns):
# Dia                 54333 non-null object
# Ano                 63649 non-null float64
# Remessa - Origem    54333 non-null object
# ContraPartida       54333 non-null object
# Lancto              54333 non-null object
# Destino             42015 non-null float64
# Complemento         54333 non-null object
# Debito              21664 non-null object
# Credito             34797 non-null object
# dtypes: float64(2), object(7)
# memory usage: 4.9+ MB

# %%
r.Debito=r.Debito.apply(o._sanitize_float_)
r.Credito=r.Credito.apply(o._sanitize_float_)

# %%
r = r.reindex(index=np.arange(1,len(r)))
r=r.dropna(how='all')
r.head()
# Out:
#      Dia   Ano Remessa - Origem        ContraPartida               Lancto  \
# 3  02/10  2006   000000-MANUAIS  8.1.7.06.00.0 279.0  00019 0004602584-01
# 4    NaN  2006              NaN                  NaN                  NaN
# 5  02/10  2006     002276-CP001  1.8.8.92.00.4 760.2  00019 0004569188-01
# 6  02/10  2006     002276-CP001  1.8.8.92.00.4 805.6  00019 0004569189-01
# 7  02/10  2006     002276-CP001  4.1.1.85.99.1 001.7  00019 0004569190-01
#
#    Destino                                        Complemento      Debito  \
# 3       19  INTEGRAÇAO DEWIN  EST DE LANÇ  4583382 CADAST ...   171709.87
# 4      NaN                                                NaN         NaN
# 5       19               INTEGRACAO CONTAS A PAGAR  Via Caixa   332960.21
# 6       19    INTEGRACAO CONTAS A PAGAR  Debito Caixa Ec.Fed.   100088.95
# 7       19       INTEGRACAO CONTAS A PAGAR  Conta Corrente DE  7880000.00
#
#    Credito
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN

# %%
rr = r[r.Dia.notnull()]
rr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54333 entries, 3 to 63663
# Data columns (total 9 columns):
# Dia                 54333 non-null object
# Ano                 54333 non-null float64
# Remessa - Origem    54333 non-null object
# ContraPartida       54333 non-null object
# Lancto              54333 non-null object
# Destino             42015 non-null float64
# Complemento         54333 non-null object
# Debito              20600 non-null float64
# Credito             33732 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 4.1+ MB

# %%
rr.Ano=rr.Ano.astype(int)
# Out:
# /home/milcent/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:2177: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
rr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54333 entries, 3 to 63663
# Data columns (total 9 columns):
# Dia                 54333 non-null object
# Ano                 54333 non-null int64
# Remessa - Origem    54333 non-null object
# ContraPartida       54333 non-null object
# Lancto              54333 non-null object
# Destino             42015 non-null float64
# Complemento         54333 non-null object
# Debito              20600 non-null float64
# Credito             33732 non-null float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 4.1+ MB

# %%
rr.to_csv('table.csv', sep = '\t', encoding='utf-8')

# %% [markdown]
# ## Iniciar daqui caso não precise manipular o arquivo em Excell

# %%
rr = pd.read_csv('table.csv', sep='\t', index_col=1,dayfirst=True,parse_dates={'Data':[1,2]})

# %%
rr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54333 entries, 3 to 63663
# Data columns (total 8 columns):
# Data                54333 non-null datetime64[ns]
# Remessa - Origem    54333 non-null object
# ContraPartida       54333 non-null object
# Lancto              54333 non-null object
# Destino             42015 non-null float64
# Complemento         54333 non-null object
# Debito              20600 non-null float64
# Credito             33732 non-null float64
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 3.7+ MB

# %%
b = o.Analysis(rr.Credito)
# Out:
# Initialized sequence with 33732 registries.

# %%
b.info()
# Out:
# <class 'ben_oop.Analysis'>
# Int64Index: 33732 entries, 13 to 63663
# Data columns (total 1 columns):
# Seq    33732 non-null float64
# dtypes: float64(1)
# memory usage: 527.1 KB

# %% [markdown]
# ###  Arrumar mantissas

# %% [markdown]
# ### Continuar a consertar mantissas - reler bibliografia antes

# %%
b.prepare()

# %%
b.info()
# Out:
# <class 'ben_oop.Analysis'>
# Int64Index: 33732 entries, 13 to 63663
# Data columns (total 6 columns):
# Seq    33732 non-null float64
# ZN     33732 non-null int64
# FD     33732 non-null int64
# SD     33732 non-null int64
# FTD    33732 non-null int64
# LTD    33732 non-null object
# dtypes: float64(1), int64(4), object(1)
# memory usage: 1.8+ MB

# %%
c = b.firstTwoDigits()
# Out:
# ---Test performed on 33732 registries.---
#
#
# The top 20 Z scores are:
#
#              Expected     Found     Z_test
# First_2_Dig
# 50           0.008600  0.013904  10.548942
# 30           0.014240  0.019892   8.760910
# 60           0.007179  0.010821   7.923301
# 70           0.006160  0.009042   6.763755
# 90           0.004799  0.006848   5.446065
# 40           0.010724  0.013637   5.194367
# 25           0.017033  0.020633   5.109644
# 92           0.004695  0.002935   4.729194
# 14           0.029963  0.026029   4.238627
# 15           0.028029  0.031810   4.207075
# 10           0.041393  0.045743   4.010985
# 20           0.021189  0.024250   3.903283
# 35           0.012234  0.014141   3.185078
# 80           0.005395  0.006611   3.048576
# 59           0.007299  0.005899   3.020215
# 21           0.020203  0.017965   2.921793
# 45           0.009545  0.011028   2.800832
# 19           0.022276  0.020129   2.672090
# 91           0.004746  0.003765   2.622677
# 13           0.032185  0.029705   2.580735
#
# The Mean Absolute Deviation is 0.00103810167029
# For the First Two Digits:
# 			- 0.0000 to 0.0012: Close Conformity
# 			- 0.0012 to 0.0018: Acceptable Conformity
# 			- 0.0018 to 0.0022: Marginally Acceptable Conformity
# 			- Above 0.0022: Nonconformity

# %%
b.firstDigit()
# Out:
# ---Test performed on 33732 registries.---
#
#
# The highest Z scores are:
#
#            Expected     Found    Z_test
# First_Dig
# 4          0.096910  0.099490  1.601789
# 3          0.124939  0.127653  1.507815
# 1          0.301030  0.297581  1.380982
# 8          0.051153  0.049656  1.247498
# 6          0.066947  0.068451  1.105617
# 2          0.176091  0.174463  0.784919
# 9          0.045757  0.045091  0.586057
# 5          0.079181  0.079776  0.404457
# 7          0.057992  0.057838  0.120771
#
# The Mean Absolute Deviation is 0.0016430628249
# For the First DigitS:
# 			- 0.0000 to 0.0006: Close Conformity
# 			- 0.0006 to 0.0012: Acceptable Conformity
# 			- 0.0012 to 0.0015: Marginally Acceptable Conformity
# 			- Above 0.0015: Nonconformity

# %%
b.secondDigit()
# Out:
# ---Test performed on 33732 registries.---
#
#
# The highest Z scores are:
#
#          Expected     Found     Z_test
# Sec_Dig
# 0        0.119679  0.150866  17.646398
# 5        0.096677  0.109095   7.717713
# 4        0.100308  0.092523   4.759402
# 9        0.084997  0.078738   4.122080
# 3        0.104330  0.097533   4.083199
# 2        0.108821  0.102810   3.545162
# 1        0.113890  0.108087   3.354856
# 6        0.093375  0.088225   3.250810
# 8        0.087570  0.084341   2.097883
# 7        0.090352  0.087780   1.647629
#
# The Mean Absolute Deviation is 0.00872087272386
# For the Second DigitS:
# 			- 0.0000 to 0.0008: Close Conformity
# 			- 0.0008 to 0.0010: Acceptable Conformity
# 			- 0.0010 to 0.0012: Marginally Acceptable Conformity
# 			- Above 0.0012: Nonconformity

# %%
lt = b.lastTwoDigits()
# Out:
# ---Test performed on 33732 registries.---
#
#
# The top 20 Z scores are:
#
#             Expected     Found      Z_test
# Last_2_Dig
# 00          0.010101  0.295921  524.971201
# 50          0.010101  0.025851   28.928015
# 27          0.010101  0.004565   10.167376
# 40          0.010101  0.015475    9.870373
# 80          0.010101  0.015267    9.489221
# 77          0.010101  0.005099    9.187268
# 63          0.010101  0.005099    9.187268
# 61          0.010101  0.005129    9.132818
# 88          0.010101  0.005188    9.023917
# 98          0.010101  0.005247    8.915016
# 49          0.010101  0.005247    8.915016
# 41          0.010101  0.005307    8.806115
# 99          0.010101  0.005455    8.533863
# 73          0.010101  0.005455    8.533863
# 20          0.010101  0.014615    8.291312
# 60          0.010101  0.014586    8.236861
# 47          0.010101  0.005633    8.207161
# 53          0.010101  0.005662    8.152711
# 21          0.010101  0.005692    8.098260
# 71          0.010101  0.005722    8.043810

# %%
b.duplicates(top_Rep=20)
# Out:
# ---Test performed on 33732 registries.---
#
#
# The 20 most frequent numbers are:
#
#       Counts   Percent
# 150       93  0.275703
# 100       91  0.269774
# 50        85  0.251986
# 1000      80  0.237164
# 2000      80  0.237164
# 300       78  0.231234
# 200       76  0.225305
# 3000      75  0.222341
# 700       73  0.216412
# 500       73  0.216412
# 400       70  0.207518
# 1500      69  0.204554
# 450       68  0.201589
# 600       64  0.189731
# 5000      61  0.180837
# 350       55  0.163050
# 30        52  0.154156
# 250       51  0.151192
# 900       49  0.145263
# 1200      45  0.133404

# %% [markdown]
# ###  Começar a trabalhar no mapeamento da sequência original com base nos achados da análise.
