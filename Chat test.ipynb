# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
x = np.arange(10)
y = np.array([15,12,9,19,22,36,7,24,30,5])

# %%
fig, ax = plt.subplots()
ax.bar(x,y)
ax.set_xticks(x + .4)
ax.set_xticklabels(x)
#ax.get_position()
# Out:
# <img src="data:image/png;base64,...">
# Bbox([[0.125, 0.1], [0.9, 0.9]])
